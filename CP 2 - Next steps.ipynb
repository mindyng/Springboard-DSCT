# %%
import json
from pandas.io.json import json_normalize

# %%
#ACTIVITY

#Get Daily Activity Summary 

DaySum = [{
"activities": [],
"goals": [{
"activeMinutes": 30,
"caloriesOut": 1977,
"distance": 8.05,
"floors": 10,
"steps": 8000
}],
"summary": [{
"activeScore": -1,
"activityCalories": 1259,
"caloriesBMR": 1100,
"caloriesOut": 2079,
"distances": [
{
"activity": "total",
"distance": 10.34
},
{
"activity": "tracker",
"distance": 10.34
},
{
"activity": "loggedActivities",
"distance": 0
},
{
"activity": "veryActive",
"distance": 2.36
},
{
"activity": "moderatelyActive",
"distance": 0.39
},
{
"activity": "lightlyActive",
"distance": 7.56
},
{
"activity": "sedentaryActive",
"distance": 0
}
],
"elevation": 48.77,
"fairlyActiveMinutes": 11,
"floors": 16,
"heartRateZones": [
{
"caloriesOut": 1584.9834,
"max": 94,
"min": 30,
"minutes": 1311,
"name": "Out of Range"
},
{
"caloriesOut": 264.71172,
"max": 131,
"min": 94,
"minutes": 66,
"name": "Fat Burn"
},
{
"caloriesOut": 103.80552,
"max": 159,
"min": 131,
"minutes": 15,
"name": "Cardio"
},
{
"caloriesOut": 98.76048,
"max": 220,
"min": 159,
"minutes": 13,
"name": "Peak"
}
],
"lightlyActiveMinutes": 366,
"marginalCalories": 658,
"restingHeartRate": 51,
"sedentaryMinutes": 743,
"steps": 16248,
"veryActiveMinutes": 40
}]
}]

# %%
a = json_normalize(DaySum, 'goals')

# %%
a #for values to appear, need to make sure feature and values are within dic within a list

#(These are my baseline values)
# Out:
#    activeMinutes  caloriesOut  distance  floors  steps
# 0             30         1977      8.05      10   8000

# %%
#On small scale:

##relevant features##
small_X = a.drop('caloriesOut', axis = 1)
small_X
# Out:
#    activeMinutes  distance  floors  steps
# 0             30      8.05      10   8000

# %%
small_y = a[['caloriesOut']]
small_y
# Out:
#    caloriesOut
# 0         1977

# %%
b = json_normalize(DaySum, 'summary')

# %%
b #These are acutal features I want to use in my Matrix X,y; need to figure out how to get multiple entries with dates attached

#Solution: Further down in notebook: will grab relevant feature values within a month's span and join these features on day
#in order to get multiple feature readings per day for multiple days
# Out:
#    activeScore  activityCalories  caloriesBMR  caloriesOut  \
# 0           -1              1259         1100         2079
#
#                                            distances  elevation  \
# 0  [{u'distance': 10.34, u'activity': u'total'}, ...      48.77
#
#    fairlyActiveMinutes  floors  \
# 0                   11      16
#
#                                       heartRateZones  lightlyActiveMinutes  \
# 0  [{u'max': 94, u'caloriesOut': 1584.9834, u'min...                   366
#
#    marginalCalories  restingHeartRate  sedentaryMinutes  steps  \
# 0               658                51               743  16248
#
#    veryActiveMinutes
# 0                 40

# %%
b['distances']
# Out:
# 0    [{u'distance': 10.34, u'activity': u'total'}, ...
# Name: distances, dtype: object

# %%
#Candidate Features

##'elevation', 'fairlyActiveMinutes', 'steps', 'veryActiveMinutes'

#Candidate y values. These are going to be run one at a time for every feature set

##'activeScore', 'activityCalories', 'caloriesBMR', 'caloriesOut', 'marginalCalories'

##e.g. 'elevation', 'fairlyActiveMinutes', 'steps', 'veryActiveMinutes' -> 'activeScore'
    # 'elevation', 'fairlyActiveMinutes', 'steps', 'veryActiveMinutes' -> 'activityCalories'

# %%
# new = old[['A', 'C', 'D']].copy()

med_X = b[['elevation', 'fairlyActiveMinutes', 'floors', 'steps', 'veryActiveMinutes']].copy()
med_X
# Out:
#    elevation  fairlyActiveMinutes  floors  steps  veryActiveMinutes
# 0      48.77                   11      16  16248                 40

# %%
med_y_sample1 = b[['activeScore']]
med_y_sample1
# Out:
#    activeScore
# 0           -1

# %%
med_y_sample2 = b[['activityCalories']]
med_y_sample2
# Out:
#    activityCalories
# 0              1259

# %%
#Get elevation Time Series

elev = [{
"activities-elevation": [
{
"dateTime": "2017-05-01",
"value": "67"
},
{
"dateTime": "2017-05-02",
"value": "30"
},
{
"dateTime": "2017-05-03",
"value": "27"
},
{
"dateTime": "2017-05-04",
"value": "39"
},
{
"dateTime": "2017-05-05",
"value": "18"
},
{
"dateTime": "2017-05-06",
"value": "51"
},
{
"dateTime": "2017-05-07",
"value": "48"
},
{
"dateTime": "2017-05-08",
"value": "27"
},
{
"dateTime": "2017-05-09",
"value": "33"
},
{
"dateTime": "2017-05-10",
"value": "27"
},
{
"dateTime": "2017-05-11",
"value": "15"
},
{
"dateTime": "2017-05-12",
"value": "21"
},
{
"dateTime": "2017-05-13",
"value": "21"
},
{
"dateTime": "2017-05-14",
"value": "15"
},
{
"dateTime": "2017-05-15",
"value": "3"
},
{
"dateTime": "2017-05-16",
"value": "6"
},
{
"dateTime": "2017-05-17",
"value": "3"
},
{
"dateTime": "2017-05-18",
"value": "33"
},
{
"dateTime": "2017-05-19",
"value": "24"
},
{
"dateTime": "2017-05-20",
"value": "64"
},
{
"dateTime": "2017-05-21",
"value": "24"
},
{
"dateTime": "2017-05-22",
"value": "54"
},
{
"dateTime": "2017-05-23",
"value": "24"
},
{
"dateTime": "2017-05-24",
"value": "36"
},
{
"dateTime": "2017-05-25",
"value": "24"
},
{
"dateTime": "2017-05-26",
"value": "18"
},
{
"dateTime": "2017-05-27",
"value": "36"
},
{
"dateTime": "2017-05-28",
"value": "42"
},
{
"dateTime": "2017-05-29",
"value": "76"
},
{
"dateTime": "2017-05-30",
"value": "27"
},
{
"dateTime": "2017-05-31",
"value": "21"
}
]
}]

# %%
c = json_normalize(elev, 'activities-elevation')
c
# Out:
#       dateTime value
# 0   2017-05-01    67
# 1   2017-05-02    30
# 2   2017-05-03    27
# 3   2017-05-04    39
# 4   2017-05-05    18
# 5   2017-05-06    51
# 6   2017-05-07    48
# 7   2017-05-08    27
# 8   2017-05-09    33
# 9   2017-05-10    27
# 10  2017-05-11    15
# 11  2017-05-12    21
# 12  2017-05-13    21
# 13  2017-05-14    15
# 14  2017-05-15     3
# 15  2017-05-16     6
# 16  2017-05-17     3
# 17  2017-05-18    33
# 18  2017-05-19    24
},
{
"dateTime": "2017-05-20",
"value": "479"
},
{
"dateTime": "2017-05-21",
"value": "584"
},
{
"dateTime": "2017-05-22",
"value": "1105"
},
{
"dateTime": "2017-05-23",
"value": "879"
},
{
"dateTime": "2017-05-24",
"value": "1298"
},
{
"dateTime": "2017-05-25",
"value": "921"
},
{
"dateTime": "2017-05-26",
"value": "1117"
},
{
"dateTime": "2017-05-27",
"value": "722"
},
{
"dateTime": "2017-05-28",
"value": "827"
},
{
"dateTime": "2017-05-29",
"value": "689"
},
{
"dateTime": "2017-05-30",
"value": "1022"
},
{
"dateTime": "2017-05-31",
"value": "886"
}
]
}]

# %%
h = json_normalize(ActCal, 'activities-activityCalories')
h
# Out:
#       dateTime value
# 0   2017-05-01   748
# 1   2017-05-02  1281
# 2   2017-05-03  1230
# 3   2017-05-04  1402
# 4   2017-05-05  1020
# 5   2017-05-06  1181
# 6   2017-05-07   836
# 7   2017-05-08  1028
# 8   2017-05-09   787
# 9   2017-05-10  1117
# 10  2017-05-11  1202
# 11  2017-05-12  1066
# 12  2017-05-13   576
# 13  2017-05-14   364
# 14  2017-05-15   413
# 15  2017-05-16   147
# 16  2017-05-17  1080
# 17  2017-05-18  1159
# 18  2017-05-19  1165
# 19  2017-05-20   479
# 20  2017-05-21   584
# 21  2017-05-22  1105
# 22  2017-05-23   879
# 23  2017-05-24  1298
# 24  2017-05-25   921
# 25  2017-05-26  1117
# 26  2017-05-27   722
# 27  2017-05-28   827
# 28  2017-05-29   689
# 29  2017-05-30  1022
# 30  2017-05-31   886

# %%
import pandas as pd

first_merge = pd.merge(c, h, on='dateTime', how='outer', suffixes=('_elevation', '_activityCalories'))
first_merge
# Out:
#       dateTime value_elevation value_activityCalories
# 0   2017-05-01              67                    748
# 1   2017-05-02              30                   1281
# 2   2017-05-03              27                   1230
# 3   2017-05-04              39                   1402
# 4   2017-05-05              18                   1020
# 5   2017-05-06              51                   1181
# 6   2017-05-07              48                    836
# 7   2017-05-08              27                   1028
# 8   2017-05-09              33                    787
# 9   2017-05-10              27                   1117
# 10  2017-05-11              15                   1202
# 11  2017-05-12              21                   1066
# 12  2017-05-13              21                    576
# 13  2017-05-14              15                    364
# 14  2017-05-15               3                    413
# 15  2017-05-16               6                    147
# 16  2017-05-17               3                   1080
# 17  2017-05-18              33                   1159
# 18  2017-05-19              24                   1165
# 19  2017-05-20              64                    479
# 20  2017-05-21              24                    584
# 21  2017-05-22              54                   1105
# 22  2017-05-23              24                    879
# 23  2017-05-24              36                   1298
# 24  2017-05-25              24                    921
# 25  2017-05-26              18                   1117
# 26  2017-05-27              36                    722
# 27  2017-05-28              42                    827
# 28  2017-05-29              76                    689
# 29  2017-05-30              27                   1022
# 30  2017-05-31              21                    886

# %%
second_merge = pd.merge(pd.merge(first_merge,d,on='dateTime'),e,on='dateTime', suffixes=('_fairlyActiveMinutes', '_floors'))
second_merge
# Out:
#       dateTime value_elevation value_activityCalories  \
# 0   2017-05-01              67                    748
# 1   2017-05-02              30                   1281
# 2   2017-05-03              27                   1230
# 3   2017-05-04              39                   1402
# 4   2017-05-05              18                   1020
# 5   2017-05-06              51                   1181
# 6   2017-05-07              48                    836
# 7   2017-05-08              27                   1028
# 8   2017-05-09              33                    787
# 9   2017-05-10              27                   1117
# 10  2017-05-11              15                   1202
# 11  2017-05-12              21                   1066
# 12  2017-05-13              21                    576
# 13  2017-05-14              15                    364
# 14  2017-05-15               3                    413
# 15  2017-05-16               6                    147
# 16  2017-05-17               3                   1080
# 17  2017-05-18              33                   1159
# 18  2017-05-19              24                   1165
# 19  2017-05-20              64                    479
# 20  2017-05-21              24                    584
# 21  2017-05-22              54                   1105
# 22  2017-05-23              24                    879
# 23  2017-05-24              36                   1298
# 24  2017-05-25              24                    921
# 25  2017-05-26              18                   1117
# 26  2017-05-27              36                    722
# 27  2017-05-28              42                    827
# 28  2017-05-29              76                    689
# 29  2017-05-30              27                   1022
# 30  2017-05-31              21                    886
#
#    value_fairlyActiveMinutes value_floors
# 0                         13           22
# 1                          5           10
# 2                          8            9
# 3                         19           13
# 4                         21            6
# 5                          2           17
# 6                          6           16
# 7                          5            9
# 8                          0           11
# 9                          9            9
# 10                         8            5
# 11                         7            7
# 12                         0            7
# 13                         0            5
# 14                         0            1
# 15                         0            2
# 16                         4            1
# 17                         9           11
# 18                         7            8
# 19                         0           21
# 20                         0            8
# 21                         2           18
# 22                         0            8
# 23                         6           12
# 24                         0            8
# 25                         4            6
# 26                         0           12
# 27                         8           14
# 28                         0           25
# 29                         0            9
# 30                         0            7

# %%
#Final Merge
final_merge = pd.merge(pd.merge(second_merge,f,on='dateTime'),g,on='dateTime', suffixes=('_steps', '_veryActiveMinutes'))
final_merge
# Out:
#       dateTime value_elevation value_activityCalories  \
# 0   2017-05-01              67                    748
# 1   2017-05-02              30                   1281
# 2   2017-05-03              27                   1230
# 3   2017-05-04              39                   1402
# 4   2017-05-05              18                   1020
# 5   2017-05-06              51                   1181
# 6   2017-05-07              48                    836
# 7   2017-05-08              27                   1028
# 8   2017-05-09              33                    787
# 9   2017-05-10              27                   1117
# 10  2017-05-11              15                   1202
# 11  2017-05-12              21                   1066
# 12  2017-05-13              21                    576
# 13  2017-05-14              15                    364
# 14  2017-05-15               3                    413
# 15  2017-05-16               6                    147
# 16  2017-05-17               3                   1080
# 17  2017-05-18              33                   1159
# 18  2017-05-19              24                   1165
# 19  2017-05-20              64                    479
# 20  2017-05-21              24                    584
# 21  2017-05-22              54                   1105
# 22  2017-05-23              24                    879
# 23  2017-05-24              36                   1298
# 24  2017-05-25              24                    921
# 25  2017-05-26              18                   1117
# 26  2017-05-27              36                    722
# 27  2017-05-28              42                    827
# 28  2017-05-29              76                    689
# 29  2017-05-30              27                   1022
# 30  2017-05-31              21                    886
#
#    value_fairlyActiveMinutes value_floors value_steps value_veryActiveMinutes
# 0                         13           22        7302                      36
# 1                          5           10       17029                      28
# 2                          8            9       14127                      33
# 3                         19           13       16047                      39
# 4                         21            6       12701                       0
# 5                          2           17       18224                      65
# 6                          6           16        8640                      34
# 7                          5            9       10984                      46
# 8                          0           11       10865                       0
# 9                          9            9       12975                      40
# 10                         8            5       15855                      23
# 11                         7            7       12083                      29
# 12                         0            7        5655                       0
# 13                         0            5        3909                       0
# 14                         0            1         588                      35
# 15                         0            2        1461                       0
# 16                         4            1       12318                      35
# 17                         9           11       14154                      39
# 18                         7            8       13037                      43
# 19                         0           21        3669                      21
# 20                         0            8        4643                      21
# 21                         2           18       12861                      46
# 22                         0            8       11037                       0
# 23                         6           12       15763                      37
# 24                         0            8       11624                       0
# 25                         4            6       12987                      35
# 26                         0           12        6801                      21
# 27                         8           14        9253                      28
# 28                         0           25        5633                      21
# 29                         0            9       12264                       0
# 30                         0            7       11430                       0

# %%
final_merge.head()
# Out:
#      dateTime value_elevation value_activityCalories  \
# 0  2017-05-01              67                    748
# 1  2017-05-02              30                   1281
# 2  2017-05-03              27                   1230
# 3  2017-05-04              39                   1402
# 4  2017-05-05              18                   1020
#
#   value_fairlyActiveMinutes value_floors value_steps value_veryActiveMinutes
# 0                        13           22        7302                      36
# 1                         5           10       17029                      28
# 2                         8            9       14127                      33
# 3                        19           13       16047                      39
# 4                        21            6       12701                       0

# %%
final_merge.describe()
# Out:
#           dateTime value_elevation value_activityCalories  \
# count           31              31                     31
# unique          31              18                     30
# top     2017-05-10              24                   1117
# freq             1               4                      2
#
#        value_fairlyActiveMinutes value_floors value_steps  \
# count                         31           31          31
# unique                        11           18          31
# top                            0            9       10865
# freq                          13            4           1
#
#        value_veryActiveMinutes
# count                       31
# unique                      15
# top                          0
# freq                         9

# %%
final_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 0 to 30
# Data columns (total 7 columns):
# dateTime                     31 non-null object
# value_elevation              31 non-null object
# value_activityCalories       31 non-null object
# value_fairlyActiveMinutes    31 non-null object
# value_floors                 31 non-null object
# value_steps                  31 non-null object
# value_veryActiveMinutes      31 non-null object
# dtypes: object(7)
# memory usage: 1.9+ KB

# %%
#Need to make a copy of main DF before modifying it for analysis.

DF_copy = final_merge.copy()
DF_copy
# Out:
#       dateTime value_elevation value_activityCalories  \
# 0   2017-05-01              67                    748
# 1   2017-05-02              30                   1281
# 2   2017-05-03              27                   1230
# 3   2017-05-04              39                   1402
# 4   2017-05-05              18                   1020
# 5   2017-05-06              51                   1181
# 6   2017-05-07              48                    836
# 7   2017-05-08              27                   1028
# 8   2017-05-09              33                    787
# 9   2017-05-10              27                   1117
# 10  2017-05-11              15                   1202
# 11  2017-05-12              21                   1066
# 12  2017-05-13              21                    576
# 13  2017-05-14              15                    364
# 14  2017-05-15               3                    413
# 15  2017-05-16               6                    147
# 16  2017-05-17               3                   1080
# 17  2017-05-18              33                   1159
# 18  2017-05-19              24                   1165
# 19  2017-05-20              64                    479
# 20  2017-05-21              24                    584
# 21  2017-05-22              54                   1105
# 22  2017-05-23              24                    879
# 23  2017-05-24              36                   1298
# 24  2017-05-25              24                    921
# 25  2017-05-26              18                   1117
# 26  2017-05-27              36                    722
# 27  2017-05-28              42                    827
# 28  2017-05-29              76                    689
# 29  2017-05-30              27                   1022
# 30  2017-05-31              21                    886
#
#    value_fairlyActiveMinutes value_floors value_steps value_veryActiveMinutes
# 0                         13           22        7302                      36
# 1                          5           10       17029                      28
# 2                          8            9       14127                      33
# 3                         19           13       16047                      39
# 4                         21            6       12701                       0
# 5                          2           17       18224                      65
# 6                          6           16        8640                      34
# 7                          5            9       10984                      46
# 8                          0           11       10865                       0
# 9                          9            9       12975                      40
# 10                         8            5       15855                      23
# 11                         7            7       12083                      29
# 12                         0            7        5655                       0
# 13                         0            5        3909                       0
# 14                         0            1         588                      35
# 15                         0            2        1461                       0
# 16                         4            1       12318                      35
# 17                         9           11       14154                      39
# 18                         7            8       13037                      43
# 19                         0           21        3669                      21
# 20                         0            8        4643                      21
# 21                         2           18       12861                      46
# 22                         0            8       11037                       0
# 23                         6           12       15763                      37
# 24                         0            8       11624                       0
# 25                         4            6       12987                      35
# 26                         0           12        6801                      21
# 27                         8           14        9253                      28
# 28                         0           25        5633                      21
# 29                         0            9       12264                       0
# 30                         0            7       11430                       0

# %%
DF_copy.head()
# Out:
#      dateTime value_elevation value_activityCalories  \
# 0  2017-05-01              67                    748
# 1  2017-05-02              30                   1281
# 2  2017-05-03              27                   1230
# 3  2017-05-04              39                   1402
# 4  2017-05-05              18                   1020
#
#   value_fairlyActiveMinutes value_floors value_steps value_veryActiveMinutes
# 0                        13           22        7302                      36
# 1                         5           10       17029                      28
# 2                         8            9       14127                      33
# 3                        19           13       16047                      39
# 4                        21            6       12701                       0

# %%
DF_copy2 = DF_copy.copy()

# %%
DF_copy2.head() #with dateTime; for further data manipulation
# Out:
#      dateTime value_elevation value_activityCalories  \
# 0  2017-05-01              67                    748
# 1  2017-05-02              30                   1281
# 2  2017-05-03              27                   1230
# 3  2017-05-04              39                   1402
# 4  2017-05-05              18                   1020
#
#   value_fairlyActiveMinutes value_floors value_steps value_veryActiveMinutes
# 0                        13           22        7302                      36
# 1                         5           10       17029                      28
# 2                         8            9       14127                      33
# 3                        19           13       16047                      39
# 4                        21            6       12701                       0

# %%
del DF_copy['dateTime']

# %%
DF_copy #No dateTime; now ready for Correlation Matrix/Scatter Matrix Plot
# Out:
#    value_elevation value_activityCalories value_fairlyActiveMinutes  \
# 0               67                    748                        13
# 1               30                   1281                         5
# 2               27                   1230                         8
# 3               39                   1402                        19
# 4               18                   1020                        21
# 5               51                   1181                         2
# 6               48                    836                         6
# 7               27                   1028                         5
# 8               33                    787                         0
# 9               27                   1117                         9
# 10              15                   1202                         8
# 11              21                   1066                         7
# 12              21                    576                         0
# 13              15                    364                         0
# 14               3                    413                         0
# 15               6                    147                         0
# 16               3                   1080                         4
# 17              33                   1159                         9
# 18              24                   1165                         7
# 19              64                    479                         0
# 20              24                    584                         0
# 21              54                   1105                         2
# 22              24                    879                         0
# 23              36                   1298                         6
# 24              24                    921                         0
# 25              18                   1117                         4
# 26              36                    722                         0
# 27              42                    827                         8
# 28              76                    689                         0
# 29              27                   1022                         0
# 30              21                    886                         0
#
#    value_floors value_steps value_veryActiveMinutes
# 0            22        7302                      36
# 1            10       17029                      28
# 2             9       14127                      33
# 3            13       16047                      39
# 4             6       12701                       0
# 5            17       18224                      65
# 6            16        8640                      34
# 7             9       10984                      46
# 8            11       10865                       0
# 9             9       12975                      40
# 10            5       15855                      23
# 11            7       12083                      29
# 12            7        5655                       0
# 13            5        3909                       0
# 14            1         588                      35
# 15            2        1461                       0
# 16            1       12318                      35
# 17           11       14154                      39
# 18            8       13037                      43
# 19           21        3669                      21
# 20            8        4643                      21
# 21           18       12861                      46
# 22            8       11037                       0
# 23           12       15763                      37
# 24            8       11624                       0
# 25            6       12987                      35
# 26           12        6801                      21
# 27           14        9253                      28
# 28           25        5633                      21
# 29            9       12264                       0
# 30            7       11430                       0

# %%
##Linear Regression

# %%
# (a) Train the model with all May data points, except for
# the last two in the timeline (a.k.a. held-out points, a.k.a. test set).

#DF without dateTime and without value_activityCalories needed for training set.

a = DF_copy.drop('value_activityCalories', axis = 1)
b = DF_copy['value_activityCalories']

trainx = a[:29]
trainy = b[:29]

testx = a[29:]
testy = b[29:]

testy
# Out:
# 29    1022
# 30     886
# Name: value_activityCalories, dtype: object

# %%
#Training Linear Regression (L.R.) Model

from sklearn.linear_model import LinearRegression
from sklearn import linear_model

lm = linear_model.LinearRegression().fit(trainx, trainy)
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm.predict(trainx)
# Out:
# array([  820.5230089 ,  1287.23877994,  1157.69189234,  1340.2152441 ,
#         1070.20730917,  1424.02279479,   821.98646721,   998.3375003 ,
#          827.84046877,  1118.24002761,  1236.64836236,  1029.56635689,
#          542.68074962,   448.65151711,   368.32496298,   317.27257781,
#         1055.48665606,  1177.42054073,  1120.38588873,   496.89049595,
#          541.9954829 ,  1065.34270315,   844.54376801,  1242.292891  ,
#          877.72097183,  1081.66204511,   654.65635013,   856.56769135,
#          598.58649514])

# %%
#Graph L.R. model. This is based on one set of predictions for a span of 29 days.

from bokeh.plotting import figure, output_file, show

output_file("line.html")

p = figure(plot_width=400, plot_height=400)

# add a line renderer
p.line(list(range(30)), lm.predict(trainx), line_width=2)

show(p)
# Out:
# /Users/mindyng/anaconda2/lib/python2.7/site-packages/bokeh/models/sources.py:89: BokehUserWarning: ColumnDataSource's columns must be of the same length
#   lambda: warnings.warn("ColumnDataSource's columns must be of the same length", BokehUserWarning))

# %%
#Now predict activity_Calories
lm.predict(testx)
# Out:
# array([ 911.56644244,  869.08339373])

# %%
#Comparing these values to the actual values:
testy
# Out:
# 29    1022
# 30     886
# Name: value_activityCalories, dtype: object

# %%
# first prediction is not as close as second prediction.

# %%
# (b) Compute RMSE and actual residuals for training set

from sklearn.metrics import mean_squared_error
import numpy as np

calories_predictions = lm.predict(trainx)
lin_mse = mean_squared_error(trainy, calories_predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse #RMSE for training set
# Out:
# 71.449922709584357

# %%
#actual residuals on training set

# residuals = actual label values - predicted label values

calories_predictions #predicted label values

trainy = np.array(trainy) #actual label values

trainresid1 = (trainy) - (calories_predictions)
trainresid1

##Can't get residuals!!! even though var types are equivalent...
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-132-5ff679a28f2f> in <module>()
#       7 trainy = np.array(trainy) #actual label values
#       8
# ----> 9 trainresid1 = (trainy) - (calories_predictions)
#      10 trainresid1
#      11
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'

# %%
# (c) Compute RMSE and actual residuals for test set

calories_predictions2 = lm.predict(testx)
lin_mse = mean_squared_error(testy, calories_predictions2)
lin_rmse = np.sqrt(lin_mse)
lin_rmse #RMSE for test set
# Out:
# 78.999184179352127

# %%
#actual residuals for test set

# residuals = actual label values - predicted label values

calories_predictions2 #predicted label values

testy = np.array(testy) #actual label values

trainresid2 = (testy) - (calories_predictions2)
trainresid2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-137-f795d013afe6> in <module>()
#       7 testy = np.array(testy) #actual label values
#       8
# ----> 9 trainresid2 = (testy) - (calories_predictions2)
#      10 trainresid2
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'

# %%
# (d) Show predicted versus actual scatter plot, and plot (for test set)
# the line y = x as a reference

# from bokeh.plotting import figure, output_file, show

# output_file("patch.html")

# p = figure(plot_width=400, plot_height=400)

# p.multi_line([np.array(testy)],[calories_predictions2], 
#              color=["firebrick", "navy"], alpha=[0.8, 0.3], line_width=4)

# show(p)

###This multiline graph will output the wrong x-axis. Need diagonal to see if
# this error in axis assignment will be corrected.

##Not multiline. This graph is to see output as single line on graph.

from bokeh.plotting import figure, output_file, show

output_file("line.html")

p = figure(plot_width=400, plot_height=400)

# add a line renderer
p.line(np.array(testy), calories_predictions2, line_width=2)#x = actual, y = predicted

show(p)
# Out:
# /Users/mindyng/anaconda2/lib/python2.7/site-packages/bokeh/models/sources.py:89: BokehUserWarning: ColumnDataSource's columns must be of the same length
#   lambda: warnings.warn("ColumnDataSource's columns must be of the same length", BokehUserWarning))
# /Users/mindyng/anaconda2/lib/python2.7/site-packages/bokeh/models/sources.py:89: BokehUserWarning: ColumnDataSource's columns must be of the same length
#   lambda: warnings.warn("ColumnDataSource's columns must be of the same length", BokehUserWarning))

# %%
np.array(testy)
# Out:
# array(['1022', '886'], dtype=object)

# %%
calories_predictions2
# Out:
# array([ 911.56644244,  869.08339373])

# %%
# (e) Show residuals scatter plot, and plot the line y = 0
# as a reference

# %%
# (2) If you can get the data for June, then repeat (1) with
# May data as your training set, and June data as your test set

# %%
##Decision Trees

# %%
# (a) Train the model with all May data points, except for
# the last two in the timeline (a.k.a. held-out points, a.k.a. test set).

from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor()
tree_reg.fit(trainx,trainy)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_split=1e-07,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
# (b) Compute RMSE and actual residuals for training set

calories_predictions3 = tree_reg.predict(trainx)
tree_mse = mean_squared_error(trainy, calories_predictions3)
tree_rmse = np.sqrt(tree_mse)
tree_rmse #RMSE for training set
#Is really prediction this good? No error at all?
# Out:
# 0.0

# %%
#actual residuals for training set

# residuals = actual training values - predicted training values

calories_predictions3 #predicted label values

trainy = np.array(trainy) #actual label values

trainresid3 = (trainy) - (calories_predictions3)
trainresid3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-138-1b89aa63c2d1> in <module>()
#       7 trainy = np.array(trainy) #actual label values
#       8
# ----> 9 trainresid3 = (trainy) - (calories_predictions3)
#      10 trainresid3
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'

# %%
# (c) Compute RMSE and actual residuals for test set

# %%
calories_predictions4 = tree_reg.predict(testx)
tree_mse = mean_squared_error(testy, calories_predictions4)
tree_rmse = np.sqrt(tree_mse)
tree_rmse #RMSE for test set
# Out:
# 75.584389922787622

# %%
#actual residuals for test set

# residuals = actual training values - predicted training values

calories_predictions4 #predicted label values

trainy = np.array(testy) #actual label values

trainresid4 = (testy) - (calories_predictions4)
trainresid14
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-139-5d275d2f3cc7> in <module>()
#       8 trainy = np.array(testy) #actual label values
#       9
# ---> 10 trainresid4 = (testy) - (calories_predictions4)
#      11 trainresid14
#
# ValueError: operands could not be broadcast together with shapes (2,) (29,)

# %%
# (d) Show predicted versus actual scatter plot, and plot the line y = x as a reference

from bokeh.plotting import figure, output_file, show

output_file("line.html")

p = figure(plot_width=400, plot_height=400)

# add a line renderer
p.line(np.array(testy), calories_predictions4, line_width=2)#x = actual, y = predicted

show(p)

# %%
testy
# Out:
# array(['1022', '886'], dtype=object)

# %%
calories_predictions4
# Out:
# array([ 921.,  921.])

# %%
# (e) Show residuals scatter plot, and plot the line y = 0
# as a reference

# %%
##Random Forests

# %%
# (a) Train the model with all May data points, except for
# the last two in the timeline (a.k.a. held-out points, a.k.a. test set).

from sklearn.ensemble import RandomForestRegressor
forest_reg = RandomForestRegressor()
forest_reg.fit(trainx, trainy)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)

# %%
# (b) Compute RMSE and actual residuals for training set

calories_predictions5 = forest_reg.predict(trainx)
forest_mse = mean_squared_error(trainy, calories_predictions5)
forest_rmse = np.sqrt(forest_mse)
forest_rmse #RMSE for training set
# Out:
# 42.694370944479637

# %%
#actual residuals for training set

# residuals = actual training values - predicted training values

calories_predictions5 #predicted label values

trainy = np.array(trainy) #actual label values

trainresid5 = (trainy) - (calories_predictions5)
trainresid5
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-140-42134ee86c3e> in <module>()
#       7 trainy = np.array(trainy) #actual label values
#       8
# ----> 9 trainresid5 = (trainy) - (calories_predictions5)
#      10 trainresid5
#
# ValueError: operands could not be broadcast together with shapes (2,) (29,)

# %%
# (c) Compute RMSE and actual residuals for test set

calories_predictions6 = forest_reg.predict(testx)
forest_mse = mean_squared_error(testy, calories_predictions6)
forest_rmse = np.sqrt(forest_mse)
forest_rmse #RMSE for test set
# Out:
# 20.302955449884642

# %%
#actual residuals for test set

# residuals = actual training values - predicted training values

calories_predictions6 #predicted label values

testy = np.array(trainy) #actual label values

trainresid6 = (testy) - (calories_predictions6)
trainresid6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-142-aac2ac558d96> in <module>()
#       7 testy = np.array(trainy) #actual label values
#       8
# ----> 9 trainresid6 = (testy) - (calories_predictions6)
#      10 trainresid6
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'

# %%
# (d) Show predicted versus actual scatter plot, and plot
# the line y = x as a reference

from bokeh.plotting import figure, output_file, show

output_file("line.html")

p = figure(plot_width=400, plot_height=400)

# add a line renderer
p.line(np.array(testy), calories_predictions6, line_width=2)#x = actual, y = predicted

show(p)

# %%
# (e) Show residuals scatter plot, and plot the line y = 0
# as a reference

# %%
# (f) Show a table that relates actual values, predicted values,
# and residuals for each pair, for each algorithm

# %%
# (2) If you can get the data for June, then repeat (1) with
# May data as your training set, and June data as your test set
